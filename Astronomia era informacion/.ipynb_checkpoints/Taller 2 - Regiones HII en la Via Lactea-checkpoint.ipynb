# %% [markdown]
# # Repaso acerca del uso de Python

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import urllib
# %matplotlib inline

# %% [markdown]
# ## Actividad 1
#
# Estudiar la distribución espacial de las nebulosas de emisión o regiones HII en nuestra Galaxia. Buscamos

# %%
data_url="https://github.com/rpmunoz/PentaUC/tree/master/Astronomia era informacion/data/regiones_HII_WISE.txt"
url=urllib.URLopener()
url.retrieve(data_url, "regiones_HII_WISE.txt")

#data=pd.read_csv('data/regiones_HII_21cm.txt', sep=',', comment='#', header=0)
#data.head()
# Out:
#    id  longitud  distancia
# 0   4      10.3       18.7
# 1   5      12.8        4.2
# 2   8      15.1        2.5
# 3  11      18.6        2.2
# 4  12      19.1       13.4

# %%
fig,ax=plt.subplots(figsize=(10,10))
ax = plt.axes(polar="true")
plt.plot(data['longitud'], data['distancia'], marker='o', linestyle='None')

# %%
data=pd.read_csv('data/regiones_HII_WISE.txt', sep=',', comment='#', header=0)
data.head()
# Out:
#    id  longitud  latitud  radio  distancia
# 0   1     0.649   -0.080    0.7        7.8
# 1   2     0.729   -0.103    0.1        8.5
# 2   3     9.599    0.199    3.5        5.2
# 3   4     9.613    0.206    3.5        5.2
# 4   5     9.614    0.200    3.5        5.2

# %%
fig,ax=plt.subplots(figsize=(10,10))
ax = plt.axes(polar="true")
plt.plot(data['longitud'], data['distancia'], marker='o', linestyle='None')

# %%
fig,ax=plt.subplots(figsize=(10,10))
ax = plt.axes(polar="true")
plt.plot(data['longitud'], data['radio'], marker='o', linestyle='None')

# %%
x=data['distancia']*np.sin(data['longitud']*np.pi/180)
y=data['distancia']*np.cos(data['longitud']*np.pi/180)

# %%
fig,ax=plt.subplots(figsize=(10,10))
plt.scatter(x,y,marker='o')

# %% [markdown]
# ## Actividad 2
#
# Hacer un histograma de la distribucion
